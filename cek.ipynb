# %%
import pandas as pd
df = pd.read_csv('hasil_fps_akhir.csv')

# %%
df.plot.line(title="FPS Pada Video dengan YOLOv7").set(xlabel='Video Frame',ylabel='Frame Per Second ( FPS )')
# Out:
# [Text(0.5, 0, 'Video Frame'), Text(0, 0.5, 'Frame Per Second ( FPS )')]

# %%
import pandas as pd
df = pd.read_csv('hasil_fps_akhir.csv')
df.plot.line(title="FPS Pada Video dengan YOLOv7").set(xlabel='Frames',ylabel='Frame Per Second ( FPS )')
# Out:
# [Text(0.5, 0, 'Frames'), Text(0, 0.5, 'Frame Per Second ( FPS )')]
